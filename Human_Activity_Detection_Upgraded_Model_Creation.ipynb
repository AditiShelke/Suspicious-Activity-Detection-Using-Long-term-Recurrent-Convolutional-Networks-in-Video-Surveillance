# %% [markdown]
# # Download and Unzip Dataset

# %%
import zipfile

# %%
#with zipfile.ZipFile('running-20240520T181542Z-001.zip', 'r') as zip_ref:
    #zip_ref.extractall('Capstone project')

# %%
#with zipfile.ZipFile('run.zip', 'r') as zip_ref:
    #zip_ref.extractall('Capstone project')

# %% [markdown]
# # Import Required Libraries

# %%
# !pip install pafy youtube-dl moviepy

# %%
# !pip install moviepy

# %%
#import os
#from moviepy.editor import VideoFileClip

#def convert_mp4_to_avi(input_path, output_path):
    # Load the mp4 file
   # clip = VideoFileClip(input_path)
    
    # Write the video to an avi file
    #clip.write_videofile(output_path, codec='png')
    
    # Close the clip
    #clip.close()

#def convert_all_videos_in_folder(input_folder, output_folder):
    # Ensure the output folder exists
    #os.makedirs(output_folder, exist_ok=True)
    
    # Iterate through all files in the input folder
    #for filename in os.listdir(input_folder):
       # if filename.endswith('.mp4'):
           # input_path = os.path.join(input_folder, filename)
           # output_filename = os.path.splitext(filename)[0] + '.avi'
            #output_path = os.path.join(output_folder, output_filename)
           # convert_mp4_to_avi(input_path, output_path)
           # print(f'Converted {input_path} to {output_path}')

# Define the input and output folders
#input_folder = 'Dataset/Fighting'
#output_folder = 'converted_to_avi'

# Convert all videos in the input folder
#convert_all_videos_in_folder(input_folder, output_folder)

# %%
pip install opencv-python
# Out:
# Collecting opencv-pythonNote: you may need to restart the kernel to use updated packages.
#
#   Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
#      ---------------------------------------- 38.6/38.6 MB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.0 in c:\users\mill\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (1.24.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\mill\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install numpy
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
pip install tensorflow==2.13.0
# Out:
# Requirement already satisfied: tensorflow==2.13.0 in c:\users\mill\anaconda3\lib\site-packages (2.13.0)
# WARNING: Ignoring invalid distribution -umpy (c:\users\mill\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\mill\anaconda3\lib\site-packages)
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: tensorflow-intel==2.13.0 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (24.3.7)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (16.0.6)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.22.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (20.4)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (49.2.0.post20200714)
# Requirement already satisfied: six>=1.12.0 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.4.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (4.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.11.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.62.1)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.13.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.13.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\mill\anaconda3\lib\site-packages (from tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\mill\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.34.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\mill\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.28.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\mill\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mill\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\mill\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.24.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\mill\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\mill\anaconda3\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.0.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\mill\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.1.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\mill\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mill\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\mill\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\mill\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\mill\appdata\roaming\python\python38\site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (6.5.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\mill\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\mill\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\mill\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mill\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (2020.6.20)
# Requirement already satisfied: zipp>=0.5 in c:\users\mill\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.1.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\mill\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\mill\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.0->tensorflow==2.13.0) (3.2.2)

# %%
pip install --upgrade h5py
# Out:
# Requirement already satisfied: h5py in c:\users\mill\anaconda3\lib\site-packages (3.11.0)Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\mill\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\mill\anaconda3\lib\site-packages)
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Requirement already satisfied: numpy>=1.17.3 in c:\users\mill\anaconda3\lib\site-packages (from h5py) (1.22.1)

# %%
import os
import cv2
import pafy
import math
import numpy as np
import random
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

from moviepy.editor import *
# %matplotlib inline

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Select Randomness

# %%
seed_constant = 5
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %% [markdown]
# # View the dataset

# %%
import os
import cv2
import random
import matplotlib.pyplot as plt

# Update the path to your dataset directory
dataset_directory = 'Dataset'

# View the dataset
plt.figure(figsize=(20, 20))

# List all class directories
all_classes_names = os.listdir(dataset_directory)

for counter, class_name in enumerate(all_classes_names, 1):
    # List all video files in the current class directory
    class_path = os.path.join(dataset_directory, class_name)
    video_files_names_list = os.listdir(class_path)
    
    if not video_files_names_list:
        continue  # Skip if no video files in the class directory
    
    # Select a random video file from the current class
    selected_video_file_name = random.choice(video_files_names_list)
    video_path = os.path.join(class_path, selected_video_file_name)
    
    # Read a frame from the selected video
    video_reader = cv2.VideoCapture(video_path)
    video_reader.set(1, 25)  # Set to read the 25th frame
    success, bgr_frame = video_reader.read()
    video_reader.release()
    
    if not success:
        continue  # Skip if unable to read the frame
    
    # Resize and convert frame to RGB
    bgr_frame = cv2.resize(bgr_frame, (224, 224))
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)
    
    # Put class name text on the frame
    cv2.putText(rgb_frame, class_name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 200, 255), 2)
    
    # Display the frame
    plt.subplot(5, 4, counter)
    plt.imshow(rgb_frame)
    plt.axis('off')

plt.show()

# %% [markdown]
# # Set Dataset Variables

# %%
# Set Dataset Variables
IMAGE_HEIGHT, IMAGE_WIDTH = 64, 64
SEQUENCE_LENGTH = 30
DATASET_DIR = "Dataset"
CLASSES_LIST = ["walking", "fighting", "running"]

# %% [markdown]
# # Data pre-processing

# %%
# Frame extraction function
def frames_extraction(video_path):
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count / SEQUENCE_LENGTH), 1)

    for frame_counter in range(SEQUENCE_LENGTH):
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
        success, frame = video_reader.read()
        if not success:
            break

        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        normalized_frame = resized_frame / 255.0
        frames_list.append(normalized_frame)

    video_reader.release()
    return frames_list

# %%
# Dataset creation function
def create_dataset():
    features = []
    labels = []
    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of Class: {class_name}')
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        for file_name in files_list:
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)
            frames = frames_extraction(video_file_path)
            if len(frames) == SEQUENCE_LENGTH:
                features.append(frames)
                labels.append(class_index)
    features = np.asarray(features)
    labels = np.array(labels)
    return features, labels

# %%
# Load dataset
features, labels = create_dataset()
# Out:
# Extracting Data of Class: walking
# Extracting Data of Class: fighting
# Extracting Data of Class: running

# %%
# Using Keras's to_categorical method to convert labels into one-hot-encoded vectors
one_hot_encoded_labels = to_categorical(labels)

# %%
# Data augmentation using ImageDataGenerator
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest'
)

# %%
# Split the Data into Train (75%) and Test Set (25%)
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size=0.25, shuffle=True, random_state=seed_constant)
features = None
labels = None

# %% [markdown]
# # Model Creation LRCN (Long-term Recurrent Convolutional Network)

# %%
def create_LRCN_model():
    model = Sequential()

    # First convolutional layer
    model.add(TimeDistributed(Conv2D(96, (11, 11), strides=(4, 4), activation='relu'), input_shape=(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D(pool_size=(3, 3), strides=(2, 2))))

    # Second convolutional layer
    model.add(TimeDistributed(Conv2D(256, (5, 5), padding='same', activation='relu')))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D(pool_size=(3, 3), strides=(2, 2))))

    # Third convolutional layer
    model.add(TimeDistributed(Conv2D(384, (3, 3), padding='same', activation='relu')))

    # Fourth convolutional layer
    model.add(TimeDistributed(Conv2D(384, (3, 3), padding='same', activation='relu')))

    # Fifth convolutional layer
    model.add(TimeDistributed(Conv2D(256, (3, 3), padding='same', activation='relu')))
    # Adjusted pooling parameters to avoid dimension issue
    model.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2), strides=(1, 1))))

    # Flatten layer to transition to fully connected layers
    model.add(TimeDistributed(Flatten()))

    # LSTM layer
    model.add(LSTM(32))

    # Fully connected layers
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(4096, activation='relu'))
    model.add(Dropout(0.5))
    
    # Output layer
    model.add(Dense(len(CLASSES_LIST), activation='softmax'))

    model.summary()
    return model

# %%
# Create the model
model = create_LRCN_model()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_10 (TimeD  (None, 30, 14, 14, 96)    34944
#  istributed)
#
#  time_distributed_11 (TimeD  (None, 30, 14, 14, 96)    384
#  istributed)
#
#  time_distributed_12 (TimeD  (None, 30, 6, 6, 96)      0
#  istributed)
#
#  time_distributed_13 (TimeD  (None, 30, 6, 6, 256)     614656
#  istributed)
#
#  time_distributed_14 (TimeD  (None, 30, 6, 6, 256)     1024
#  istributed)
#
#  time_distributed_15 (TimeD  (None, 30, 2, 2, 256)     0
#  istributed)
#
#  time_distributed_16 (TimeD  (None, 30, 2, 2, 384)     885120
#  istributed)
#
#  time_distributed_17 (TimeD  (None, 30, 2, 2, 384)     1327488
#  istributed)
#
#  time_distributed_18 (TimeD  (None, 30, 2, 2, 256)     884992
#  istributed)
#
#  time_distributed_19 (TimeD  (None, 30, 1, 1, 256)     0
#  istributed)
#
#  time_distributed_20 (TimeD  (None, 30, 256)           0
#  istributed)
#
#  lstm (LSTM)                 (None, 32)                36992
#
#  dense (Dense)               (None, 4096)              135168
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 20714371 (79.02 MB)
# Trainable params: 20713667 (79.02 MB)
# Non-trainable params: 704 (2.75 KB)
# _________________________________________________________________

# %%
# !pip install pydot

# %%
plot_model(model, to_file = 'Suspicious_Human_Activity_LRCN_Model.png', show_shapes = True, show_layer_names = True)

# %% [markdown]
# # Model Training

# %%
# Model Training
# Create an Instance of Early Stopping Callback.
early_stopping_callback = EarlyStopping(monitor='accuracy', patience=10, mode='max', restore_best_weights=True)

# Compile the model and specify loss function, optimizer and metrics to the model.
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=["accuracy"])

# Start training the model.
model_training_history = model.fit(x=features_train, y=labels_train, epochs=70, batch_size=4, shuffle=True, validation_split=0.25, callbacks=[early_stopping_callback])
# Out:
# Epoch 1/70
# 44/44 [==============================] - 100s 2s/step - loss: 1.0452 - accuracy: 0.4629 - val_loss: 1.7071 - val_accuracy: 0.3559
# Epoch 2/70
# 44/44 [==============================] - 94s 2s/step - loss: 0.8678 - accuracy: 0.5600 - val_loss: 1.2746 - val_accuracy: 0.3220
# Epoch 3/70
# 44/44 [==============================] - 83s 2s/step - loss: 1.1312 - accuracy: 0.2971 - val_loss: 1.0882 - val_accuracy: 0.3220
# Epoch 4/70
# 44/44 [==============================] - 86s 2s/step - loss: 0.9912 - accuracy: 0.4686 - val_loss: 1.1307 - val_accuracy: 0.4576
# Epoch 5/70
# 44/44 [==============================] - 85s 2s/step - loss: 0.9075 - accuracy: 0.5429 - val_loss: 0.6945 - val_accuracy: 0.6271
# Epoch 6/70
# 44/44 [==============================] - 87s 2s/step - loss: 0.9971 - accuracy: 0.4857 - val_loss: 1.3708 - val_accuracy: 0.3220
# Epoch 7/70
# 44/44 [==============================] - 82s 2s/step - loss: 1.1157 - accuracy: 0.3600 - val_loss: 1.0660 - val_accuracy: 0.3220
# Epoch 8/70
# 44/44 [==============================] - 96s 2s/step - loss: 0.9297 - accuracy: 0.4971 - val_loss: 0.8185 - val_accuracy: 0.6441
# Epoch 9/70
# 44/44 [==============================] - 90s 2s/step - loss: 0.8961 - accuracy: 0.5943 - val_loss: 0.9927 - val_accuracy: 0.5763
# Epoch 10/70
# 44/44 [==============================] - 97s 2s/step - loss: 0.9388 - accuracy: 0.5486 - val_loss: 0.7711 - val_accuracy: 0.5932
# Epoch 11/70
# 44/44 [==============================] - 88s 2s/step - loss: 0.9827 - accuracy: 0.5486 - val_loss: 0.7012 - val_accuracy: 0.6441
# Epoch 12/70
# 44/44 [==============================] - 93s 2s/step - loss: 0.9311 - accuracy: 0.5429 - val_loss: 0.8449 - val_accuracy: 0.5932
# Epoch 13/70
# 44/44 [==============================] - 95s 2s/step - loss: 0.8657 - accuracy: 0.5143 - val_loss: 0.5892 - val_accuracy: 0.6780
# Epoch 14/70
# 44/44 [==============================] - 96s 2s/step - loss: 0.8341 - accuracy: 0.6000 - val_loss: 0.6499 - val_accuracy: 0.6441
# Epoch 15/70
# 44/44 [==============================] - 91s 2s/step - loss: 0.7825 - accuracy: 0.5771 - val_loss: 0.6958 - val_accuracy: 0.6102
# Epoch 16/70
# 44/44 [==============================] - 85s 2s/step - loss: 0.8028 - accuracy: 0.5486 - val_loss: 0.6664 - val_accuracy: 0.6271
# Epoch 17/70
# 44/44 [==============================] - 83s 2s/step - loss: 0.8566 - accuracy: 0.5543 - val_loss: 0.7434 - val_accuracy: 0.6271
# Epoch 18/70
# 44/44 [==============================] - 81s 2s/step - loss: 0.8026 - accuracy: 0.5657 - val_loss: 0.8481 - val_accuracy: 0.6102
# Epoch 19/70
# 44/44 [==============================] - 85s 2s/step - loss: 0.7248 - accuracy: 0.6286 - val_loss: 1.6182 - val_accuracy: 0.4068
# Epoch 20/70
# 44/44 [==============================] - 86s 2s/step - loss: 0.7548 - accuracy: 0.5714 - val_loss: 1.2922 - val_accuracy: 0.5424
# Epoch 21/70
# 44/44 [==============================] - 82s 2s/step - loss: 0.7520 - accuracy: 0.6114 - val_loss: 0.6988 - val_accuracy: 0.6271
# Epoch 22/70
# 44/44 [==============================] - 83s 2s/step - loss: 0.8135 - accuracy: 0.5886 - val_loss: 0.6773 - val_accuracy: 0.6271
# Epoch 23/70
# 44/44 [==============================] - 84s 2s/step - loss: 0.9426 - accuracy: 0.4629 - val_loss: 1.0991 - val_accuracy: 0.3390
# Epoch 24/70
# 44/44 [==============================] - 90s 2s/step - loss: 1.0744 - accuracy: 0.4171 - val_loss: 1.0796 - val_accuracy: 0.4407
# Epoch 25/70
# 44/44 [==============================] - 83s 2s/step - loss: 1.0463 - accuracy: 0.4457 - val_loss: 1.0541 - val_accuracy: 0.4576
# Epoch 26/70
# 44/44 [==============================] - 84s 2s/step - loss: 1.0424 - accuracy: 0.5200 - val_loss: 1.0523 - val_accuracy: 0.3220
# Epoch 27/70
# 44/44 [==============================] - 89s 2s/step - loss: 1.1767 - accuracy: 0.3543 - val_loss: 1.1134 - val_accuracy: 0.3220
# Epoch 28/70
# 44/44 [==============================] - 85s 2s/step - loss: 1.0946 - accuracy: 0.3657 - val_loss: 1.0375 - val_accuracy: 0.3559
# Epoch 29/70
# 44/44 [==============================] - 84s 2s/step - loss: 1.0893 - accuracy: 0.3657 - val_loss: 1.0486 - val_accuracy: 0.3220

# %% [markdown]
# # Save Model

# %%
# Save your Model.
model.save("Improved_Suspicious_Human_Activity_Detection_LRCN_Model1.h5")

# %% [markdown]
# # Plot Loss and Accuracy Graphs while Training

# %%
# Plot Loss and Accuracy Graphs while Training
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    '''
    This function will plot the metrics passed to it in a graph.
    Args:
        model_training_history: A history object containing a record of training and validation 
                                loss values and metrics values at successive epochs
        metric_name_1:          The name of the first metric that needs to be plotted in the graph.
        metric_name_2:          The name of the second metric that needs to be plotted in the graph.
        plot_name:              The title of the graph.
    '''

    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]

    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))

    # Plot the Graph.
    plt.plot(epochs, metric_value_1, 'blue', label=metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label=metric_name_2)

    # Add title to the plot.
    plt.title(str(plot_name))

    # Add legend to the plot.
    plt.legend()

# %%
plot_metric(model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
plot_metric(model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %% [markdown]
# # Accuracy on Test Dataset

# %%
# Accuracy on Test Dataset
# Calculate Accuracy On Test Dataset
acc = 0
for i in range(len(features_test)):
    predicted_label = np.argmax(model.predict(np.expand_dims(features_test[i], axis=0))[0])
    actual_label = np.argmax(labels_test[i])
    if predicted_label == actual_label:
        acc += 1
acc = (acc * 100) / len(labels_test)
print("Accuracy =", acc)
# Out:
# 1/1 [==============================] - 1s 844ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 65ms/step
# Accuracy = 44.87179487179487
